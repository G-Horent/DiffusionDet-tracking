# %%
import os
import pandas as pd

from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.utils.visualizer import Visualizer
import random
import cv2
import matplotlib.pyplot as plt

# %%
from MOT_dataset import get_MOT17_dataset, MOT_CLASS_NAMES

# %%
mot_train_metadata = MetadataCatalog.get("MOT17_train").set(thing_classes=MOT_CLASS_NAMES)
dataset_dicts = get_MOT17_dataset('datasets/MOT17/train')

# %%
dataset_dicts_test = get_MOT17_dataset('datasets/MOT17/test')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_23180/1705122726.py in <module>
# ----> 1 dataset_dicts_test = get_MOT17_dataset('datasets/MOT17/test')
#
# ~/DiffusionDet-main/MOT_dataset.py in get_MOT17_dataset(path_dir)
#      20     for directory in sorted(list_dir):
#      21         file_gt = pd.read_csv(os.path.join(path_dir, directory, 'gt', 'gt.txt'), sep=',', header=None,
# ---> 22                               names=MOT_COLUMNS_NAMES)
#      23
#      24         imgs_names = sorted(os.listdir(os.path.join(path_dir, directory, 'img1')))
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=mot_train_metadata, scale=0.5)
    out = visualizer.draw_dataset_dict(d)
    plt.imshow(out.get_image()[:,:])
    plt.show()

# %%
for i in range(10):
    print(dataset_dicts[i]['file_name'])
# Out:
# datasets/MOT17/train/MOT17-02-FRCNN/img1/000001.jpg
# datasets/MOT17/train/MOT17-02-FRCNN/img1/000002.jpg
# datasets/MOT17/train/MOT17-02-FRCNN/img1/000003.jpg
# datasets/MOT17/train/MOT17-02-FRCNN/img1/000004.jpg
# datasets/MOT17/train/MOT17-02-FRCNN/img1/000005.jpg
# datasets/MOT17/train/MOT17-02-FRCNN/img1/000006.jpg
# datasets/MOT17/train/MOT17-02-FRCNN/img1/000007.jpg
# datasets/MOT17/train/MOT17-02-FRCNN/img1/000008.jpg
# datasets/MOT17/train/MOT17-02-FRCNN/img1/000009.jpg
# datasets/MOT17/train/MOT17-02-FRCNN/img1/000010.jpg
